# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import tensorflow as tf
import os

# %%
df_pre = pd.read_csv("/Users/user/java-web-project0208/python-basic/dataset/wine.csv", header=None)
df = df_pre.sample(frac=1)

dataset = df.values
X = dataset[:, 0:12].astype(float)
Y = dataset[:, 12]

model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
MODEL_DIR = '/Users/user/java-web-project0208/python-basic/model'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# loss 값을 파일로 저장
modelpath = "/Users/user/java-web-project0208/python-basic/model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# %%
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.03965, saving model to /Users/user/java-web-project0208/python-basic/model/01-0.0396.hdf5
#
# Epoch 00002: val_loss improved from 0.03965 to 0.03789, saving model to /Users/user/java-web-project0208/python-basic/model/02-0.0379.hdf5
#
# Epoch 00003: val_loss did not improve from 0.03789
#
# Epoch 00004: val_loss improved from 0.03789 to 0.03763, saving model to /Users/user/java-web-project0208/python-basic/model/04-0.0376.hdf5
#
# Epoch 00005: val_loss did not improve from 0.03763
#
# Epoch 00006: val_loss did not improve from 0.03763
#
# Epoch 00007: val_loss did not improve from 0.03763
#
# Epoch 00008: val_loss did not improve from 0.03763
#
# Epoch 00009: val_loss did not improve from 0.03763
#
# Epoch 00010: val_loss did not improve from 0.03763
#
# Epoch 00011: val_loss did not improve from 0.03763
#
# Epoch 00012: val_loss improved from 0.03763 to 0.03710, saving model to /Users/user/java-web-project0208/python-basic/model/12-0.0371.hdf5
#
# Epoch 00013: val_loss did not improve from 0.03710
#
# Epoch 00014: val_loss did not improve from 0.03710
#
# Epoch 00015: val_loss did not improve from 0.03710
#
# Epoch 00016: val_loss did not improve from 0.03710
#
# Epoch 00017: val_loss did not improve from 0.03710
#
# Epoch 00018: val_loss did not improve from 0.03710
#
# Epoch 00019: val_loss improved from 0.03710 to 0.03657, saving model to /Users/user/java-web-project0208/python-basic/model/19-0.0366.hdf5
#
# Epoch 00020: val_loss did not improve from 0.03657
#
# Epoch 00021: val_loss did not improve from 0.03657
#
# Epoch 00022: val_loss did not improve from 0.03657
#
# Epoch 00023: val_loss did not improve from 0.03657
#
# Epoch 00024: val_loss did not improve from 0.03657
#
# Epoch 00025: val_loss did not improve from 0.03657
#
# Epoch 00026: val_loss improved from 0.03657 to 0.03625, saving model to /Users/user/java-web-project0208/python-basic/model/26-0.0363.hdf5
#
# Epoch 00027: val_loss did not improve from 0.03625
#
# Epoch 00028: val_loss improved from 0.03625 to 0.03566, saving model to /Users/user/java-web-project0208/python-basic/model/28-0.0357.hdf5
#
# Epoch 00029: val_loss did not improve from 0.03566
#
# Epoch 00030: val_loss did not improve from 0.03566
#
# Epoch 00031: val_loss did not improve from 0.03566
#
# Epoch 00032: val_loss improved from 0.03566 to 0.03522, saving model to /Users/user/java-web-project0208/python-basic/model/32-0.0352.hdf5
#
# Epoch 00033: val_loss did not improve from 0.03522
#
# Epoch 00034: val_loss improved from 0.03522 to 0.03481, saving model to /Users/user/java-web-project0208/python-basic/model/34-0.0348.hdf5
#
# Epoch 00035: val_loss did not improve from 0.03481
#
# Epoch 00036: val_loss did not improve from 0.03481
#
# Epoch 00037: val_loss did not improve from 0.03481
#
# Epoch 00038: val_loss did not improve from 0.03481
#
# Epoch 00039: val_loss did not improve from 0.03481
#
# Epoch 00040: val_loss did not improve from 0.03481
#
# Epoch 00041: val_loss did not improve from 0.03481
#
# Epoch 00042: val_loss did not improve from 0.03481
#
# Epoch 00043: val_loss did not improve from 0.03481
#
# Epoch 00044: val_loss did not improve from 0.03481
#
# Epoch 00045: val_loss did not improve from 0.03481
#
# Epoch 00046: val_loss did not improve from 0.03481
#
# Epoch 00047: val_loss did not improve from 0.03481
#
# Epoch 00048: val_loss did not improve from 0.03481
#
# Epoch 00049: val_loss did not improve from 0.03481
#
# Epoch 00050: val_loss did not improve from 0.03481
#
# Epoch 00051: val_loss did not improve from 0.03481
#
# Epoch 00052: val_loss did not improve from 0.03481
#
# Epoch 00053: val_loss did not improve from 0.03481
#
# Epoch 00054: val_loss did not improve from 0.03481
#
# Epoch 00055: val_loss did not improve from 0.03481
#
# Epoch 00056: val_loss did not improve from 0.03481
#
# Epoch 00057: val_loss improved from 0.03481 to 0.03454, saving model to /Users/user/java-web-project0208/python-basic/model/57-0.0345.hdf5
#
# Epoch 00058: val_loss did not improve from 0.03454
#
# Epoch 00059: val_loss did not improve from 0.03454
#
# Epoch 00060: val_loss did not improve from 0.03454
#
# Epoch 00061: val_loss did not improve from 0.03454
#
# Epoch 00062: val_loss did not improve from 0.03454
#
# Epoch 00063: val_loss did not improve from 0.03454
#
# Epoch 00064: val_loss did not improve from 0.03454
#
# Epoch 00065: val_loss did not improve from 0.03454
#
# Epoch 00066: val_loss did not improve from 0.03454
#
# Epoch 00067: val_loss did not improve from 0.03454
#
# Epoch 00068: val_loss did not improve from 0.03454
#
# Epoch 00069: val_loss did not improve from 0.03454
#
# Epoch 00070: val_loss did not improve from 0.03454
#
# Epoch 00071: val_loss did not improve from 0.03454
#
# Epoch 00072: val_loss did not improve from 0.03454
#
# Epoch 00073: val_loss did not improve from 0.03454
#
# Epoch 00074: val_loss did not improve from 0.03454
#
# Epoch 00075: val_loss did not improve from 0.03454
#
# Epoch 00076: val_loss did not improve from 0.03454
#
# Epoch 00077: val_loss did not improve from 0.03454
#
# Epoch 00078: val_loss did not improve from 0.03454
#
# Epoch 00079: val_loss did not improve from 0.03454
#
# Epoch 00080: val_loss did not improve from 0.03454
#
# Epoch 00081: val_loss did not improve from 0.03454
#
# Epoch 00082: val_loss did not improve from 0.03454
#
# Epoch 00083: val_loss did not improve from 0.03454
#
# Epoch 00084: val_loss did not improve from 0.03454
#
# Epoch 00085: val_loss did not improve from 0.03454
#
# Epoch 00086: val_loss did not improve from 0.03454
#
# Epoch 00087: val_loss improved from 0.03454 to 0.03423, saving model to /Users/user/java-web-project0208/python-basic/model/87-0.0342.hdf5
#
# Epoch 00088: val_loss did not improve from 0.03423
#
# Epoch 00089: val_loss did not improve from 0.03423
#
# Epoch 00090: val_loss did not improve from 0.03423
#
# Epoch 00091: val_loss did not improve from 0.03423
#
# Epoch 00092: val_loss did not improve from 0.03423
#
# Epoch 00093: val_loss did not improve from 0.03423
#
# Epoch 00094: val_loss did not improve from 0.03423
#
# Epoch 00095: val_loss improved from 0.03423 to 0.03378, saving model to /Users/user/java-web-project0208/python-basic/model/95-0.0338.hdf5
#
# Epoch 00096: val_loss did not improve from 0.03378
#
# Epoch 00097: val_loss did not improve from 0.03378
#
# Epoch 00098: val_loss did not improve from 0.03378
#
# Epoch 00099: val_loss did not improve from 0.03378
#
# Epoch 00100: val_loss did not improve from 0.03378
#
# Epoch 00101: val_loss did not improve from 0.03378
#
# Epoch 00102: val_loss did not improve from 0.03378
#
# Epoch 00103: val_loss did not improve from 0.03378
#
# Epoch 00104: val_loss did not improve from 0.03378
#
# Epoch 00105: val_loss did not improve from 0.03378
#
# Epoch 00106: val_loss did not improve from 0.03378
#
# Epoch 00107: val_loss did not improve from 0.03378
#
# Epoch 00108: val_loss improved from 0.03378 to 0.03285, saving model to /Users/user/java-web-project0208/python-basic/model/108-0.0329.hdf5
#
# Epoch 00109: val_loss improved from 0.03285 to 0.03269, saving model to /Users/user/java-web-project0208/python-basic/model/109-0.0327.hdf5
#
# Epoch 00110: val_loss did not improve from 0.03269
#
# Epoch 00111: val_loss did not improve from 0.03269
#
# Epoch 00112: val_loss did not improve from 0.03269
#
# Epoch 00113: val_loss did not improve from 0.03269
#
# Epoch 00114: val_loss did not improve from 0.03269
#
# Epoch 00115: val_loss did not improve from 0.03269
#
# Epoch 00116: val_loss did not improve from 0.03269
#
# Epoch 00117: val_loss did not improve from 0.03269
#
# Epoch 00118: val_loss did not improve from 0.03269
#
# Epoch 00119: val_loss did not improve from 0.03269
#
# Epoch 00120: val_loss did not improve from 0.03269
#
# Epoch 00121: val_loss did not improve from 0.03269
#
# Epoch 00122: val_loss did not improve from 0.03269
#
# Epoch 00123: val_loss did not improve from 0.03269
#
# Epoch 00124: val_loss did not improve from 0.03269
#
# Epoch 00125: val_loss did not improve from 0.03269
#
# Epoch 00126: val_loss did not improve from 0.03269
#
# Epoch 00127: val_loss did not improve from 0.03269
#
# Epoch 00128: val_loss did not improve from 0.03269
#
# Epoch 00129: val_loss did not improve from 0.03269
#
# Epoch 00130: val_loss did not improve from 0.03269
#
# Epoch 00131: val_loss did not improve from 0.03269
#
# Epoch 00132: val_loss did not improve from 0.03269
#
# Epoch 00133: val_loss did not improve from 0.03269
#
# Epoch 00134: val_loss did not improve from 0.03269
#
# Epoch 00135: val_loss did not improve from 0.03269
# Epoch 00136: val_loss did not improve from 0.03269
#
# Epoch 00137: val_loss did not improve from 0.03269
#
# Epoch 00138: val_loss did not improve from 0.03269
#
# Epoch 00139: val_loss did not improve from 0.03269
#
# Epoch 00140: val_loss did not improve from 0.03269
#
# Epoch 00141: val_loss improved from 0.03269 to 0.03269, saving model to /Users/user/java-web-project0208/python-basic/model/141-0.0327.hdf5
#
# Epoch 00142: val_loss did not improve from 0.03269
#
# Epoch 00143: val_loss did not improve from 0.03269
#
# Epoch 00144: val_loss did not improve from 0.03269
#
# Epoch 00145: val_loss did not improve from 0.03269
#
# Epoch 00146: val_loss did not improve from 0.03269
#
# Epoch 00147: val_loss did not improve from 0.03269
#
# Epoch 00148: val_loss did not improve from 0.03269
#
# Epoch 00149: val_loss did not improve from 0.03269
#
# Epoch 00150: val_loss did not improve from 0.03269
#
# Epoch 00151: val_loss did not improve from 0.03269
#
# Epoch 00152: val_loss did not improve from 0.03269
#
# Epoch 00153: val_loss did not improve from 0.03269
#
# Epoch 00154: val_loss did not improve from 0.03269
#
# Epoch 00155: val_loss did not improve from 0.03269
#
# Epoch 00156: val_loss did not improve from 0.03269
#
# Epoch 00157: val_loss did not improve from 0.03269
#
# Epoch 00158: val_loss did not improve from 0.03269
#
# Epoch 00159: val_loss did not improve from 0.03269
#
# Epoch 00160: val_loss did not improve from 0.03269
#
# Epoch 00161: val_loss did not improve from 0.03269
#
# Epoch 00162: val_loss did not improve from 0.03269
#
# Epoch 00163: val_loss improved from 0.03269 to 0.03201, saving model to /Users/user/java-web-project0208/python-basic/model/163-0.0320.hdf5
#
# Epoch 00164: val_loss did not improve from 0.03201
#
# Epoch 00165: val_loss did not improve from 0.03201
#
# Epoch 00166: val_loss did not improve from 0.03201
#
# Epoch 00167: val_loss did not improve from 0.03201
#
# Epoch 00168: val_loss did not improve from 0.03201
#
# Epoch 00169: val_loss did not improve from 0.03201
#
# Epoch 00170: val_loss did not improve from 0.03201
#
# Epoch 00171: val_loss did not improve from 0.03201
#
# Epoch 00172: val_loss did not improve from 0.03201
#
# Epoch 00173: val_loss did not improve from 0.03201
#
# Epoch 00174: val_loss did not improve from 0.03201
#
# Epoch 00175: val_loss did not improve from 0.03201
#
# Epoch 00176: val_loss did not improve from 0.03201
#
# Epoch 00177: val_loss did not improve from 0.03201
#
# Epoch 00178: val_loss improved from 0.03201 to 0.03140, saving model to /Users/user/java-web-project0208/python-basic/model/178-0.0314.hdf5
#
# Epoch 00179: val_loss did not improve from 0.03140
#
# Epoch 00180: val_loss did not improve from 0.03140
#
# Epoch 00181: val_loss did not improve from 0.03140
#
# Epoch 00182: val_loss did not improve from 0.03140
#
# Epoch 00183: val_loss did not improve from 0.03140
#
# Epoch 00184: val_loss did not improve from 0.03140
#
# Epoch 00185: val_loss did not improve from 0.03140
#
# Epoch 00186: val_loss did not improve from 0.03140
#
# Epoch 00187: val_loss did not improve from 0.03140
#
# Epoch 00188: val_loss did not improve from 0.03140
#
# Epoch 00189: val_loss did not improve from 0.03140
#
# Epoch 00190: val_loss did not improve from 0.03140
#
# Epoch 00191: val_loss did not improve from 0.03140
#
# Epoch 00192: val_loss did not improve from 0.03140
#
# Epoch 00193: val_loss did not improve from 0.03140
#
# Epoch 00194: val_loss did not improve from 0.03140
#
# Epoch 00195: val_loss did not improve from 0.03140
#
# Epoch 00196: val_loss did not improve from 0.03140
#
# Epoch 00197: val_loss did not improve from 0.03140
#
# Epoch 00198: val_loss did not improve from 0.03140
#
# Epoch 00199: val_loss did not improve from 0.03140
#
# Epoch 00200: val_loss did not improve from 0.03140
