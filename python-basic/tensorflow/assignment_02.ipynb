# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.callbacks import ModelCheckpoint

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import tensorflow as tf


df = pd.read_csv("/Users/user/java-web-project0208/python-basic/dataset/wdbc.data.csv")

# %%
col1=df.columns[1:2].to_list()
col2=df.columns[:1].to_list()
col3=df.columns[2:].to_list()

new_col=col2+col3+col1

df=df[new_col]

df.loc[(df.M == 'M'), 'M'] = 1
df.loc[(df.M == 'B'), 'M'] = 0

# %%
df.corr()
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")

# %%
dataset = df.values.astype(float)
X = dataset[:, 1:31]
Y = dataset[:, 31]

n_fold = 10
skf= StratifiedKFold(n_splits=n_fold, shuffle=True)

accuracy = []

for train, test in skf.split(X,Y):
    model = Sequential()
    model.add(Dense(32, input_dim=30, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy',  optimizer='adam', metrics=['accuracy'])
    history = model.fit(X[train], Y[train], epochs=100, batch_size=8, validation_data=(X[test],Y[test]))
    k_accuracy = "%.4f" % (model.evaluate(X[test], Y[test])[1])
    accuracy.append(k_accuracy)
# Out:
# Train on 511 samples, validate on 57 samples
# Epoch 1/100
# 511/511 [==============================] - 2s 4ms/sample - loss: 43.6806 - accuracy: 0.5636 - val_loss: 1.5730 - val_accuracy: 0.8596
# Epoch 2/100
# 511/511 [==============================] - 0s 723us/sample - loss: 0.9348 - accuracy: 0.8885 - val_loss: 1.1683 - val_accuracy: 0.8947
# Epoch 3/100
# 511/511 [==============================] - 0s 679us/sample - loss: 0.7127 - accuracy: 0.9022 - val_loss: 0.7332 - val_accuracy: 0.8947
# Epoch 4/100
# 511/511 [==============================] - 0s 543us/sample - loss: 0.5440 - accuracy: 0.9061 - val_loss: 0.5603 - val_accuracy: 0.9123
# Epoch 5/100
# 511/511 [==============================] - 0s 578us/sample - loss: 0.4441 - accuracy: 0.9237 - val_loss: 0.8169 - val_accuracy: 0.8596
# Epoch 6/100
# 511/511 [==============================] - 0s 588us/sample - loss: 0.4909 - accuracy: 0.9100 - val_loss: 0.5079 - val_accuracy: 0.9123
# Epoch 7/100
# ...

# %%
print("\n %.f fold accuracy: " % n_fold, accuracy)
# Out:
#  10 fold accuracy:  ['0.9474', '0.8947', '0.9649', '0.8596', '0.9649', '0.8596', '0.8947', '0.9474', '0.8929', '0.9107']

# %%
y_vloss = history.history['val_loss']
y_acc = history.history['accuracy']

x_len = np.arange(len(y_acc))

plt.plot(x_len, y_vloss, "o", c="red", markersize=3)
plt.plot(x_len, y_acc, "o", c="blue", markersize=3)

plt.show()
